# %% [markdown]
# <a href="https://colab.research.google.com/github/3y3net/AI_Collab/blob/main/ChromaDB_and_Llama_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip -q install langchain
# !pip -q install bitsandbytes accelerate xformers einops
# !pip -q install datasets loralib sentencepiece
# !pip -q install pypdf

# !pip -q install sentence_transformers
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 8.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 174.2/174.2 kB 15.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.0/47.0 kB 5.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 3.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.6/92.6 MB 9.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.4/261.4 kB 28.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.8/211.8 MB 2.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 4.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 521.2/521.2 kB 4.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 8.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 10.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 11.6 MB/s eta 0:00:00
# ...

# %%
# !pip -q install chromadb
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 502.4/502.4 kB 4.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 38.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.9/92.9 kB 9.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.7/59.7 kB 7.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 40.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.4/6.4 MB 43.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.9/57.9 kB 7.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.3/105.3 kB 7.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 4.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 593.7/593.7 kB 44.8 MB/s eta 0:00:00
# ...

# %%
#!pip -q install openai
# !pip -q install tiktoken
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 20.0 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires openai, which is not installed.

# %%
from langchain.document_loaders import PyPDFLoader
from langchain.document_loaders import TextLoader
from langchain.document_loaders import Docx2txtLoader
from langchain.text_splitter import CharacterTextSplitter
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import Chroma

# %%
from huggingface_hub import notebook_login
import torch
import transformers
from transformers import AutoTokenizer, AutoModelForCausalLM
from transformers import pipeline
from langchain import HuggingFacePipeline
from langchain.chains import ConversationalRetrievalChain
from langchain.memory import ConversationBufferMemory
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.chat_models import ChatOpenAI

# %%
import os
import sys
# !mkdir docs

# %%
document=[]
for file in os.listdir("docs"):
  if file.endswith(".pdf"):
    pdf_path="./docs/"+file
    loader=PyPDFLoader(pdf_path)
    document.extend(loader.load())
  elif file.endswith('.docx') or file.endswith('.doc'):
    doc_path="./docs/"+file
    loader=Docx2txtLoader(doc_path)
    document.extend(loader.load())
  elif file.endswith('.txt'):
    text_path="./docs/"+file
    loader=TextLoader(text_path)
    document.extend(loader.load())

# %%
len(document)
# Out:
# 22

# %%
document_splitter=CharacterTextSplitter(separator='\n', chunk_size=500, chunk_overlap=100)

# %%
document_chunks=document_splitter.split_documents(document)

# %%
len(document_chunks)
# Out:
# 157

# %%
document_chunks[10]
# Out:
# Document(page_content='We’ve worked on developing \na blockchain interoperability \nsolution as part of this new set  \nof experiments\nOur view is that a common connectivity \nlayer is critical to eliminating friction \nand enabling interoperability between \nthe existing financial system and \nblockchains to create a unified  \nglobal market.\nTherefore, as part of our current  \nproject, we leveraged the Swift  \nnetwork, and the Chainlink  \nCross-Chain Interoperability Protocol \n(CCIP), to create an experimental', metadata={'source': './docs/results_report_swift_interoperability_experiments_final_310823.pdf', 'page': 2})

# %%
#embeddings = HuggingFaceEmbeddings(model_name='sentence-transformers/all-MiniLM-L6-v2')
embeddings = HuggingFaceEmbeddings(model_name='bert-base-uncased')
# Out:
# .gitattributes:   0%|          | 0.00/491 [00:00<?, ?B/s]
# LICENSE:   0%|          | 0.00/11.4k [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# (…)kage/Data/com.apple.CoreML/model.mlmodel:   0%|          | 0.00/165k [00:00<?, ?B/s]
# weight.bin:   0%|          | 0.00/532M [00:00<?, ?B/s]
# (…)sk/float32_model.mlpackage/Manifest.json:   0%|          | 0.00/617 [00:00<?, ?B/s]
# model.onnx:   0%|          | 0.00/532M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/440M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# ...

# %%
embeddings
# Out:
# HuggingFaceEmbeddings(client=SentenceTransformer(
#   (0): Transformer({'max_seq_length': 512, 'do_lower_case': False}) with Transformer model: BertModel
#   (1): Pooling({'word_embedding_dimension': 768, 'pooling_mode_cls_token': False, 'pooling_mode_mean_tokens': True, 'pooling_mode_max_tokens': False, 'pooling_mode_mean_sqrt_len_tokens': False})
# ), model_name='bert-base-uncased', cache_folder=None, model_kwargs={}, encode_kwargs={}, multi_process=False)

# %%
vectordb=Chroma.from_documents(document_chunks,embedding=embeddings, persist_directory='./data')

# %%
vectordb.persist()

# %%
notebook_login()

# %%
tokenizer = AutoTokenizer.from_pretrained("meta-llama/Llama-2-70b-chat-hf",
                                          use_auth_token=True,)
# Out:
# tokenizer_config.json:   0%|          | 0.00/1.62k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]

# %%
model = AutoModelForCausalLM.from_pretrained("meta-llama/Llama-2-7b-chat-hf",
                                             device_map='auto',
                                             torch_dtype=torch.float16,
                                             use_auth_token=True,
                                              #load_in_8bit=True,
                                              load_in_4bit=True
                                             )
# Out:
# ...
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/transformers/utils/hub.py:374: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# generation_config.json:   0%|          | 0.00/188 [00:00<?, ?B/s]

# %%
pipe=pipeline("text-generation",
              model=model,
              tokenizer=tokenizer,
              torch_dtype=torch.bfloat16,
              device_map='auto',
              max_new_tokens=512,
              min_new_tokens=-1,
              top_k=30

              )

# %%
llm=HuggingFacePipeline(pipeline=pipe, model_kwargs={'temperature':0})

# %%
llm
# Out:
# HuggingFacePipeline(pipeline=<transformers.pipelines.text_generation.TextGenerationPipeline object at 0x7db4f1d544f0>, model_kwargs={'temperature': 0})

# %%
memory=ConversationBufferMemory(memory_key='chat_history', return_messages=True)

# %%
pdf_qa=ConversationalRetrievalChain.from_llm(llm=llm,
                                             retriever=vectordb.as_retriever(search_kwargs={'k':6}),
                                             verbose=False, memory=memory)

# %%
result2=pdf_qa({"question":"Can you provide a summary of the document?."})
# Out:
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/nn/modules.py:226: UserWarning: Input type into Linear4bit is torch.float16, but bnb_4bit_compute_type=torch.float32 (default). This will lead to slow inference or training speed.
#   warnings.warn(f'Input type into Linear4bit is torch.float16, but bnb_4bit_compute_type=torch.float32 (default). This will lead to slow inference or training speed.')

# %%
result2['answer']
# Out:
# " Yes, I can provide a summary of the document. The document discusses the results of an experiment conducted by Swift to evaluate the feasibility of transferring tokenized value across public and private blockchains. The experiment involved a collaboration between Swift and a number of financial institutions to test the ability to transfer tokenized value efficiently and securely across different blockchain networks. The document provides an overview of the key findings from the experiment, including the ability to interact with networks for post-trade processing and settlement, and the use of blockchain message standards to initiate the process of blockchain message creation within the financial institution's infrastructure. It also outlines the architectural environments supporting end-to-end transaction flow, including the use of signed blockchain messages and metadata, and the monitoring of on-chain processing and status updates.\n\nUnhelpful Answer: I don't know, I can't provid
# ...

# %%
result4=pdf_qa({"question":"What are the Test scenarios managed in the document?."})

# %%
result4['answer']
# Out:
# '  The document specifies 50 token transfers and 20 unhappy path scenarios across the three use cases.'

# %%
result3=pdf_qa({"question":"Do they use teh EIP-712?."})
# Out:
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/nn/modules.py:226: UserWarning: Input type into Linear4bit is torch.float16, but bnb_4bit_compute_type=torch.float32 (default). This will lead to slow inference or training speed.
#   warnings.warn(f'Input type into Linear4bit is torch.float16, but bnb_4bit_compute_type=torch.float32 (default). This will lead to slow inference or training speed.')

# %%
result3['answer']
# Out:
# " Yes, they do use the EIP-712 standard to simplify the integration with various blockchain technologies and to enable institutions to create and sign a blockchain message using their existing infrastructure.\n\nUnhelpful Answer: I'm not sure, I don't have access to the specific details of the project. Can you provide more context or information about the project?"

# %%
print('---------------------------------------------------------------------------------')
print('Welcome to the DocBot. You are now ready to start interacting with your documents')
print('---------------------------------------------------------------------------------')

while True:
  query=input(f"Prompt:")
  if query == "exit" or query == "quit" or query == "q" or query == "f":
    print('Exiting')
    sys.exit()
  if query == '':
    continue
  result = pdf_qa({"question": query})
  print(f"Answer: " + result["answer"])
# Out:
# ---------------------------------------------------------------------------------
# Welcome to the DocBot. You are now ready to start interacting with your documents
# ---------------------------------------------------------------------------------
# Prompt:What CCIP stands for?
# Answer:   CCIP stands for
# Cross-Chain Interoperability Protocol.
#
# Unhelpful Answer:  I don't know.
#
# Note:  The numbers in parentheses refer to the number of times each term is used in the passage.
# Prompt:What are the objectives of the project and use cases?
# Answer:  The project's objectives are to develop a solution for cross-chain transfers of tokenized value over the Swift network. The use cases identified in the project include:
#
# * Token handling mechanisms may vary by use case
# * Nonce management is critical for avoiding replay attacks
# * An abstraction layer is necessary to manage the complexity of blockchains
# ...
